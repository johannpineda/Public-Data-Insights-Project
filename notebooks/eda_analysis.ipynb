# %% [markdown]
# # 🌍 Public Data Insights Project
#
# Exploratory Data Analysis on a large-scale public dataset (100,000+ records) to identify trends in economic and social activity.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/clean_public_data.csv")

df.head()

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ## 📊 Category Distribution Analysis

# %%
category_counts = df["Category"].value_counts()

plt.figure(figsize=(8,5))

category_counts.plot(kind="bar")

plt.title("Category Distribution")

plt.ylabel("Count")

plt.show()

# %% [markdown]
# ## 🌍 City-Level Insights

# %%
city_values = df.groupby("City")["Value"].mean().sort_values()

plt.figure(figsize=(8,5))

city_values.plot(kind="bar")

plt.title("Average Value by City")

plt.ylabel("Average Value")

plt.show()

# %% [markdown]
# ## 📈 Monthly Trend Analysis

# %%
monthly_trend = df.groupby("Month")["Value"].sum()

plt.figure(figsize=(12,5))

monthly_trend.plot()

plt.title("Monthly Value Trend")

plt.ylabel("Value")

plt.show()

# %%
weekday = df["DayOfWeek"].value_counts()

plt.figure(figsize=(8,5))

weekday.plot(kind="bar")

plt.title("Activity by Day of Week")

plt.show()

# %% [markdown]
# # 🧠 Key Insights
#
# ## Category Behavior
# Some categories dominate overall activity, indicating higher user engagement.
#
# ## Geographic Trends
# Certain cities show significantly higher average values.
#
# ## Time Trends
# Activity fluctuates monthly, showing seasonal or cyclical behavior.
#
# ## Operational Insight
# Weekday patterns suggest peak usage during specific days of the week.
